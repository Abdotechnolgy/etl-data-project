# %%
import pandas as pd
nora_df = pd.read_csv('archdaily_project1.csv', header=4)

nora_df.head()
# Out:
#   https://images.adsttc.com/media/images/628f/e9b8/3253/5b3d/bbb9/e94d/large_jpg/residential-house-in-kaunas-architectural-bureau-gnatkevicius-and-partners_26.jpg?1653598706  \
# 0  https://images.adsttc.com/media/images/628f/ed...
# 1  https://images.adsttc.com/media/images/628f/f3...
# 2  https://images.adsttc.com/media/images/628f/f4...
# 3  https://images.adsttc.com/media/images/628f/ed...
# 4  https://images.adsttc.com/media/images/628f/ee...
#
#   House in Kaunas / Architectural Bureau G.Natkevicius & Partners - Exterior Photography, Windows  \
# 0  House in Kaunas / Architectural Bureau G.Natke...
# 1  House in Kaunas / Architectural Bureau G.Natke...
# 2  House in Kaunas / Architectural Bureau G.Natke...
# 3  House in Kaunas / Architectural Bureau G.Natke...
# 4  House in Kaunas / Architectural Bureau G.Natke...
#
#    image_2.jpg
# 0  image_3.jpg
# 1  image_4.jpg
# 2  image_5.jpg
# 3  image_6.jpg
# 4  image_7.jpg

# %%
nora_df.columns = ['image_url', 'caption', 'file_name']

nora_df.head()
# Out:
#                                            image_url  \
# 0  https://images.adsttc.com/media/images/628f/ed...
# 1  https://images.adsttc.com/media/images/628f/f3...
# 2  https://images.adsttc.com/media/images/628f/f4...
# 3  https://images.adsttc.com/media/images/628f/ed...
# 4  https://images.adsttc.com/media/images/628f/ee...
#
#                                              caption    file_name
# 0  House in Kaunas / Architectural Bureau G.Natke...  image_3.jpg
# 1  House in Kaunas / Architectural Bureau G.Natke...  image_4.jpg
# 2  House in Kaunas / Architectural Bureau G.Natke...  image_5.jpg
# 3  House in Kaunas / Architectural Bureau G.Natke...  image_6.jpg
# 4  House in Kaunas / Architectural Bureau G.Natke...  image_7.jpg

# %%
nora_df['project_name'] = nora_df['caption'].str.split(' - Image').str[0]

nora_df.head()
# Out:
#                                            image_url  \
# 0  https://images.adsttc.com/media/images/628f/ed...
# 1  https://images.adsttc.com/media/images/628f/f3...
# 2  https://images.adsttc.com/media/images/628f/f4...
# 3  https://images.adsttc.com/media/images/628f/ed...
# 4  https://images.adsttc.com/media/images/628f/ee...
#
#                                              caption    file_name  \
# 0  House in Kaunas / Architectural Bureau G.Natke...  image_3.jpg
# 1  House in Kaunas / Architectural Bureau G.Natke...  image_4.jpg
# 2  House in Kaunas / Architectural Bureau G.Natke...  image_5.jpg
# 3  House in Kaunas / Architectural Bureau G.Natke...  image_6.jpg
# 4  House in Kaunas / Architectural Bureau G.Natke...  image_7.jpg
#
#                                         project_name
# 0  House in Kaunas / Architectural Bureau G.Natke...
# 1  House in Kaunas / Architectural Bureau G.Natke...
# 2  House in Kaunas / Architectural Bureau G.Natke...
# ...

# %%
nora_df.to_csv('nora_data_transformed.csv', index=False)
